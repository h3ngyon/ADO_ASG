# %%
from snowflake.snowpark import Session
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path=r"../secrets.env")
# Out:
# True

# %%
session = Session.builder.getOrCreate()

# %%
session = create_session()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 session = create_session()
#
# Cell In[6], line 13, in create_session()
#       2 if os.getenv("SNOWFLAKE_ACCOUNT"):
#       3     return Session.builder.getOrCreate()
#       5 return Session.builder.configs({
#       6     "account": os.getenv("SF_ACCOUNT"),
#       7     "user": os.getenv("SF_USER"),
#       8     "authenticator": "externalbrowser",
#       9     "role": os.getenv("SF_ROLE"),
#      10     "warehouse": os.getenv("SF_WAREHOUSE"),
#      11     "database": os.getenv("SF_DATABASE"),
#      12     "schema": os.getenv("SF_SCHEMA")
# ---> 13 }).create()
#
# File c:\Users\User\anaconda3\Lib\site-packages\snowflake\snowpark\session.py:524, in Session.SessionBuilder.create(self)
#     522     _add_session(session)
#     523 else:
# ...
