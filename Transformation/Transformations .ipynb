# %%
# import libraries
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt

from sklearn.pipeline import make_pipeline

# %%
# List of tables to be processed and wrangled 
table_names=['']

# %%
# %pip install ipython-sql sqlalchemy
# Install sqlalchemy to run sql commands in jupyter notebook
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install snowflake-snowpark-python[pandas]
# Install Snowflake Snowpark to allow notebook to communicate to Snowflake
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imported libraries for Snowflake connection
import json
from snowflake.snowpark import Session  # to create a session to connect to Snowflake

def get_session():                      # function to create Snowflake session
    connection_config = {
        "account": "SFEDU02-OOB65461",
        "user": "FERRET",
        "password": "eyJraWQiOiI1Njg4MjY3NTcyNDQ5Mjg2IiwiYWxnIjoiRVMyNTYifQ.eyJwIjoiODY3OTYwNzU0NTM6ODY3OTYwNzkxMDkiLCJpc3MiOiJTRjoxMDQ5IiwiZXhwIjoxNzY5NTAxMDE5fQ.zrjjc5kfofWqpLa55KmqjRuirPFhK0z6OXB5j6DfzkMOvhrFWI1RlBhfjsoeHsWid6XsIFVd-5YzqNCnYPRldQ",
        "role": "TRAINING_ROLE",
        "warehouse": "FERRET_WH",
        "database": "GRP1_ASG",
        "schema": "ASG",
        "client_session_keep_alive": True   # ensure that connection stays alive even with inactivity
    }
    return Session.builder.configs(connection_config).create()

session = get_session()
print(f"Connected to Snowflake: {session.get_current_account()}")
# Out:
# Connected to Snowflake: "SFEDU02-OOB65461"
